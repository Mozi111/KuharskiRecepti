# %%
# naložimo paket
import pandas as pd

# naložimo razpredelnico, s katero bomo delali
recepti = pd.read_csv('recepti.csv', index_col='id')

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 20 vrstic
pd.options.display.max_rows = 20

# %%
recepti
# Out:
#                                             naslov     objava           avtor  \
# id
# 10029                       Mešano meso izpod peke   5.5.2007         mamamia
# 10035                         Salsa -Tuna tortilje   7.5.2007       A.Jerneja
# 10068  Narastek iz ajdove kaše, skute in zelenjave  15.5.2007           fresh
# 10070                    Božanska čokoladna rulada  16.5.2007         vitajan
# 10074                                    Bajadera   16.5.2007         stana.r
# 10078                             Atomski "štrudl"  17.5.2007           lidia
# 10079                      Jogurtovo - sadna torta  18.5.2007         stana.r
# 10083                            Višnjeve kroglice  18.5.2007         valeria
# 10088     Jagodna torta z jogurtovo - skutno kremo  21.5.2007        ksenjako
# 10096                   Biskvit brez jajc in mleka  23.5.2007          barb_b
# ...                                            ...        ...             ...
# 9805                          Rojstnodnevno pecivo   3.3.2007  mlada kuharica
# 9855                           Čokoladna torta Rok  19.3.2007          KatkaD
# 9858                                    Bačo torta  19.3.2007          šjorca
# 9871                                     Kifeljčki  22.3.2007        Katjuška
# 9878                              Biskvitno pecivo  23.3.2007          anitae
# 9882                             Čokoladni muffini  24.3.2007       baby girl
# 9924                              Zelenjavna obara  31.3.2007    Anja Poljšak
# 9949                                 Skutini cmoki   5.4.2007     Veronika :)
# 9966                             Zelenjavni kuskus  12.4.2007       bellatrix
# 9988                           Spomladansko pecivo  21.4.2007            nemo
#
#                                spol   priprava             kolicina  stmnenj  \
# id
# 10029                        ženska  120 minut        za deset oseb     12.0
# 10035                        ženska   15 minut        za 2 tortilji     21.0
# 10068  spol ni določen oz. marsovec   90 minut              4 osebe     10.0
# 10070                        ženska   60 minut                  NaN    197.0
# 10074                        ženska   30 minut                  NaN     63.0
# 10078                        ženska   75 minut                  NaN     74.0
# 10079                        ženska  240 minut                  NaN     75.0
# 10083                        ženska   60 minut           30 kroglic     23.0
# 10088                        ženska   45 minut             16 kosov     49.0
# 10096                        ženska   60 minut                  NaN     15.0
# ...                             ...        ...                  ...      ...
# 9805                         ženska        NaN                  NaN     34.0
# 9855                         ženska   60 minut             16 kosov     32.0
# 9858                         ženska        NaN                  NaN     40.0
# 9871                         ženska  180 minut  100 mini kifeljčkov     67.0
# 9878                         ženska   60 minut                  NaN     42.0
# 9882   spol ni določen oz. marsovec        NaN       za 12 muffinov     35.0
# 9924                         ženska   90 minut              4 osebe     10.0
# 9949                         ženska   45 minut              4 osebe     12.0
# 9966   spol ni določen oz. marsovec   30 minut          3-4 porcije     22.0
# 9988                         ženska   75 minut                  NaN     20.0
#
#        stfoto  zadnjafoto       kategorija     podkategorija        zdravajed
# id
# 10029     4.0  27.12.2014       mesne jedi            ostalo              NaN
# 10035     3.0   1.10.2015         eksotika     ostale dežele              NaN
# 10068     4.0    3.4.2016  zelenjavne jedi               NaN  Bolj zdrava jed
# 10070    25.0   31.1.2016          sladice            pecivo              NaN
# 10074    12.0    8.3.2016          sladice            pecivo              NaN
# 10078     7.0    3.8.2011          sladice            pecivo              NaN
# 10079    17.0   17.5.2015          sladice             torte              NaN
# 10083     7.0  25.12.2015          sladice            ostalo              NaN
# 10088    37.0   12.7.2016          sladice             torte              NaN
# 10096     1.0    6.9.2007          sladice            pecivo              NaN
# ...       ...         ...              ...               ...              ...
# 9805     72.0    6.3.2014          sladice            pecivo              NaN
# 9855      9.0   15.7.2013          sladice             torte              NaN
# 9858      7.0   28.1.2014          sladice             torte              NaN
# 9871     19.0   14.4.2014          sladice            ostalo              NaN
# 9878      2.0   10.4.2008          sladice            pecivo              NaN
# 9882     13.0   19.4.2014          sladice            ostalo              NaN
# 9924      2.0   16.6.2008   juhe in zakuhe   zelenjavne juhe              NaN
# 9949      2.0    9.4.2012          priloge             cmoki              NaN
# 9966      5.0   26.5.2015  zelenjavne jedi               NaN              NaN
# 9988      1.0   20.4.2007          sladice            pecivo              NaN
#
# [1200 rows x 12 columns]

# %%
recepti_po_kategorijah = recepti.groupby('kategorija')
recepti_po_kategorijah.size()
# Out:
# kategorija
# eksotika            14
# enolončnice         32
# gobje jedi           8
# jajčne jedi          9
# juhe in zakuhe      28
# kruh                62
# mesne jedi          95
# morska hrana        19
# napitki             12
# omake               13
#                   ...
# otroška hrana        2
# ozimnica            48
# predjedi            26
# prikuhe              1
# priloge             47
# sirove jedi         13
# sladice            687
# solate               7
# testenine           20
# zelenjavne jedi     41
# dtype: int64

# %%
recepti_po_spolih = recepti.groupby('spol')
recepti_po_spolih.size()
# Out:
# spol
# moški                            69
# spol ni določen oz. marsovec    148
# ženska                          958
# dtype: int64

# %%
recepti_po_spolih['stmnenj'].mean()
# Out:
# spol
# moški                           38.594203
# spol ni določen oz. marsovec    48.135135
# ženska                          47.176594
# Name: stmnenj, dtype: float64

# %%
recepti_po_spolih['stfoto'].mean()
# Out:
# spol
# moški                            6.838235
# spol ni določen oz. marsovec     9.591837
# ženska                          10.845263
# Name: stfoto, dtype: float64

# %%
recepti_po_avtorjih = recepti.groupby('avtor')
recepti_po_avtorjih.size()
# Out:
# avtor
# *CaTh*           1
# *~Petra~*        1
# .packa.          1
# 14moniii         1
# 3.14jana         1
# 631141           2
# A.Jerneja        1
# Abby             1
# Aja              1
# Al1a             1
#                 ..
# zes5ana          6
# zima             1
# zmesnjavca       2
# ~witch~fire      1
# ČRNICA           1
# činča            1
# Šef Sebastjan    1
# šjorca           8
# žana             1
# živica           1
# dtype: int64

# %%
recepti_po_casu = recepti.groupby('priprava')
recepti_po_casu.size()
# Out:
# priprava
# 120 minut     94
# 15 minut      31
# 150 minut      4
# 180 minut     41
# 240 minut     10
# 30 minut      91
# 4+ ur         28
# 45 minut     118
# 5 minut        8
# 60 minut     142
# 75 minut      61
# 90 minut      90
# dtype: int64

# %%
recepti_po_kolicinah = recepti.groupby('kolicina')
recepti_po_kolicinah.size()
# Out:
# kolicina
#                                 1
#  približno 24 krofov            1
# (okoli 50 kosov)                1
# 1                               3
# 1 hlebec                        2
# 1 kg                            3
# 1 kg kruha                      1
# 1 kilogramski hlebček           1
# 1 krožnik                       1
# 1 liter                         1
#                                ..
# za veliko torto                 1
# za več oseb                     2
# za več sladkosnedcev            1
# za več sladkosnednežev          1
# za vso družino in prijatelje    1
# za šest oseb                    2
# za štir osebe                   1
# za štiri osebe                  4
# zs 4 osebe                      1
# čez 100 piškotov                1
# dtype: int64
